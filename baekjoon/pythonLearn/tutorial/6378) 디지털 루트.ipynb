# %%
while True:
    i = input()
    if i == "0": break
    while True:
        s = sum(map(int, list(i)))
        if len(i) == 1:
            print(s)    
            break
        else: i = str(s)
# Out:
# 24
# 6
# 39
# 3
# 0
