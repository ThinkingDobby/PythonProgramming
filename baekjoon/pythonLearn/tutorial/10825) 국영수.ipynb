# %%
inputs = []
for i in range(int(input())):
    inputs.append(input().split())
inputs.sort(key = lambda k: (-int(k[1]), int(k[2]), -int(k[3]), k[0]))   # 정렬 우선순위 설정
for i in inputs:
    print(i[0])
# Out:
# 1
# ㅁㅇㄴㄹ ㅁㅇㄴㄹ ㅁㅇㄴㄹ ㅁㅇㄴㄹ
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-3c63878f0362> in <module>
#       2 for i in range(int(input())):
#       3     inputs.append(input().split())
# ----> 4 inputs.sort(key = lambda k: (-int(k[1]), int(k[2]), -int(k[3]), k[0]))   # 정렬 우선순위 설정
#       5 for i in inputs:
#       6     print(i[0])
#
# <ipython-input-27-3c63878f0362> in <lambda>(k)
#       2 for i in range(int(input())):
#       3     inputs.append(input().split())
# ----> 4 inputs.sort(key = lambda k: (-int(k[1]), int(k[2]), -int(k[3]), k[0]))   # 정렬 우선순위 설정
#       5 for i in inputs:
#       6     print(i[0])
#
# ValueError: invalid literal for int() with base 10: 'ㅁㅇㄴㄹ'
