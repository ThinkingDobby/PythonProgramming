# %%
memo = [i * i for i in range(1, 101)]
f = int(input())
s = int(input())
l = [i for i in memo if i >= f and i <= s]
if (len(l) > 0):
    print(sum(l))
    print(l[0])
else:
    print(-1)
# Out:
# 245
# 64
