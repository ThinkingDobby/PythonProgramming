# %%
for _ in range(int(input())):
    tmp = [list(map(int, input().split())) for _ in range(9)]
    a = sum([i[0] for i in tmp])
    b = sum([i[1] for i in tmp])
    if a > b: print("Yonsei")
    elif a < b: print("Korea")
    else: print("Draw")
# Out:
# Yonsei
