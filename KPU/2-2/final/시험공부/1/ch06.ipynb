# %%
def mul(a):
    return [a * i for i in range(1, 10)]

print(mul(2))
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
print(sum([i for i in range(1, 1001) if i % 3 == 0 or i % 5 == 0]))
# Out:
# 234168

# %%
def getTotalPage(m, n):
    return (m + n - 1) // n

print(getTotalPage(5, 10))
print(getTotalPage(15, 10))
print(getTotalPage(25, 10))
print(getTotalPage(30, 10))
# Out:
# 1
# 2
# 3
# 3

# %%
with open ("a.txt", "r") as src:
    s = src.read().replace("\t", "    ")
    with open("b.txt", "w") as dest:
        dest.write(s)

# %%
import os

def search(dirname):
    try:
        filenames = os.listdir(dirname)
        for filename in filenames:
            full_filename = os.path.join(dirname, filename) # 경로 합치기
            if os.path.isdir(full_filename):
                search(full_filename)
            else:
                if os.path.splitext(full_filename)[-1] == ".py":
                    print(full_filename)
    except PermissionError:
        pass

search("c:\\")

# %%
import os

for (path, dir, files) in os.walk("c:\\"):
    for filename in files:
        if os.path.splitext(filename)[-1] == ".py":
            print(os.path.join(path, filename))
