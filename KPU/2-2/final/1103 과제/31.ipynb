# %%
l = [1,2,5,10,20,50,100,200]
memo = {i:0 for i in range(1,201)}
for i in l:
    memo[i] += 1
    for j in range(i + 1,201):
        memo[j] += memo[j - i]
        
print(memo[200])
# Out:
# 73682
