# %%
import re

p = re.compile(r"(?<!\d)0\d{2}(?=-)-\d{3,4}(?=-)-\d{4}(?!\d)")
m = p.findall("0000-1234-5666,010-1234-5678, 010-123-45678, 031-8041-0010, 123-456-7890, 010-12312-1231")
print(m)

re.search("\w", "1")
# Out:
# ['010-1234-5678', '031-8041-0010']
# <re.Match object; span=(0, 1), match='1'>

# %%
import numpy as np

np.mean([4, 9, 11])
# Out:
# 8.0

# %%
import pandas as pd

a = pd.Series([1, 2, 3, 4],['a', 'b', 'c', 'd'])
print(a)
a.index = ['b', 'a', 'e', 'a']
print(a)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# b    1
# a    2
# e    3
# a    4
# dtype: int64

# %%
import numpy as np
names = np.array(["Bob", "Joe", "Will", "Will", "Bob", "Will", "Joe"])
names[[0, 5, 1]]
# Out:
# array(['Bob', 'Will', 'Joe'], dtype='<U4')

# %%
from pandas import DataFrame
pop = {'Nevade': {2001:2.4, 2002:2.9}, 'Ohio':{2000:1.5, 2001:1.7, 2002:3.6}}
frame = DataFrame(pop)
print(frame.max(axis=0).min())
# Out:
# 2.9
