# %%
print("hello")
# Out:
# hello

# %%
a = 'Life is too short, You need Python'
print(a[28:])
print(a[-6:])
# Out:
# Python
# Python

# %%
def calc(a, b):
    return a // b, a % b

print(calc(123456, 123))
# Out:
# (1003, 87)

# %%
a = {1, 2, 3, 4}
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
[i for i in range(1, 101) if "6" in str(i)]
# Out:
# [6, 16, 26, 36, 46, 56, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 76, 86, 96]

# %%
dict1 = {"NFLX":4950,"TREX":2400,"FIZZ":1800, "XPO":1700}
dict2 = {i[0]:i[1] for i in dict1.items() if i[1] > 2000}
print(dict2)
dict2 = {i:j for (i, j) in dict1.items() if j > 2000}
print(dict2)
# Out:
# {'NFLX': 4950, 'TREX': 2400}
# {'NFLX': 4950, 'TREX': 2400}

# %%
a = """Using dict comprehension and a conditional argument
create a dictionary from the current dictionary dict1"""

al = {chr(i) for i in range(97, 123)}
print(al - set(a.lower()))
# Out:
# {'k', 'v', 'x', 'q', 'w', 'j', 'z', 'b'}

# %%
ans = []
for i in range(2, 4):
    tmp = []
    for j in range(1, 10):
        tmp.append(i * j)
    ans.append(tmp)

[[i * j for j in range(1, 10)] for i in range(2, 4)]
# Out:
# [[2, 4, 6, 8, 10, 12, 14, 16, 18], [3, 6, 9, 12, 15, 18, 21, 24, 27]]

# %%
print(sum((lambda x, y: (x + y, x * y))(2, 3)))

print(sum((lambda x: (x[0] + x[1], x[0] * x[1]))(list(map(int, input().split())))))

# %%
# with open("input.txt", 'r') as f:
#     with open("output.txt", 'w') as s:
#         while True:
#             line = f.readline().strip()
#             if not line: break
#             s.write(line + sum(map(int, line.split())) + "\n")

# %%
a = "1 2 3 4"
print(map(int, a.split()))

# %%
for g in range(T):
    data = []
    k = int(input())
    n = int(input())

    for _ in range(k+1):
        line = []
        data.append(line)
    for e in range(1,n+1):
        data[0].append(e)
    if k >1:
        for y in range(1,k+1): #1층부터 k+1층까지 
            for x in range(n): #1호 ->2호 -> --- -> n-1호까지  
                data[y].append(sum(data[y-1][:x+1]))
        result = data[k][n-1]
        print(result)
    else:
        for y in range(1,2): #1층부터 k+1층까지 
            for x in range(n): #1호 ->2호 -> --- -> n-1호까지  
                data[y].append(sum(data[y-1][:x+1]))
        result = data[k][n-1]
        print(result)
    data =[]
# Out:
# 3
# [[1, 2, 3], [1], []]
# [[1, 2, 3], [1, 3], []]
# [[1, 2, 3], [1, 3, 6], []]
# [[1, 2, 3], [1, 3, 6], [1]]
# [[1, 2, 3], [1, 3, 6], [1, 4]]
# [[1, 2, 3], [1, 3, 6], [1, 4, 10]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-656055014ccd> in <module>
#      15         for y in range(1,k+2): #1층부터 k+1층까지
#      16             for x in range(n): #1호 ->2호 -> --- -> n-1호까지
# ---> 17                 data[y].append(sum(data[y-1][:x+1]))
#      18                 print(data)
#      19         result = data[k-2][n-1]
#
# IndexError: list index out of range

# %%
from itertools import combinations

n,m = map(int,input().split())
result = []
result_sum = []
score = 0
k = 0
data = list(map(int, input().split()))
result = list(combinations(data,3))
result = sorted(result,reverse=False)
for k in range(len(result)):
    result_sum.append(sum(result[k]))
result_sum = sorted(result_sum,reverse=False)

i = 0
while True:
    if result_sum[i] > m: break
    score = result_sum[i]
    i += 1
print(score)

while score <= m:
    score = result_sum[k]
    print(score)
    k=k+1
# Out:
# 21

# %%
for i in range(1, 100):
    if (1280 - i * 2) % 3 == 0:
        print(i)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 61
# 64
# 67
# 70
# 73
# 76
# 79
# 82
# 85
# 88
# 91
# 94
# 97
