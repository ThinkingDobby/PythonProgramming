# %%
print("asdf")
# Out:
# asdf

# %%
print("123")
# Out:
# 123

# %%
a = [1, 2, 3, 4]
b = ['a', 'b', 'c', 'd']
print(a[0] + b[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f8d215d09a03> in <module>
#       1 a = [1, 2, 3, 4]
#       2 b = ['a', 'b', 'c', 'd']
# ----> 3 print(a[0] + b[0])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
