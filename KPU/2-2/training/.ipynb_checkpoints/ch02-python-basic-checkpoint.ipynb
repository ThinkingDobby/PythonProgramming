# %% [markdown]
# ### 슬라이싱

# %%
a = "Life is too short. You need Python."

# %%
print(a[28:34])
# Out:
# Python

# %%
print(a[a.index('P'):-1])
# Out:
# Python

# %% [markdown]
# ### 튜플을 이용

# %%
def calc(a, b):
    return a // b, a % b

# %%
print(calc(123456, 123))
# Out:
# (1003, 87)

# %% [markdown]
# ### count

# %%
a = "1112211111"
print(a.find("22"))
# Out:
# 3

# %%
a = [1, 2, 3, 4]
b = ['a', 'b', 'c', 'd']
print(a + b)
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 'd']

# %%
[(x, x**2) for x in range(6)]
# Out:
# [(0, 0), (1, 1), (2, 4), (3, 9), (4, 16), (5, 25)]

# %% [markdown]
# ### 리스트 내포 이용한 flatten

# %%
vec = [[1,2,3], [4,5,6], [7,8,9]]
[num for elem in vec for num in elem]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
nums = [i for i in range(1, 101)]
ans = [j for j in nums if '6' in str(j)]
print(ans)
# Out:
# [6, 16, 26, 36, 46, 56, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 76, 86, 96]

# %%
a = {1: 'a', 2: 'b', 0: 'c', 'abc': 5}
a['abc']
# Out:
# 5

# %%
d = {i:i*10 for i in a}
d
# Out:
# {1: 10, 2: 20, 0: 0, 'abc': 'abcabcabcabcabcabcabcabcabcabc'}

# %%
dict1={"NFLX":4950,"TREX":2400,"FIZZ":1800, "XPO":1700}
dict2 = {i:j for i,j in dict1.items() if j > 2000}
print(dict2)
# Out:
# {'NFLX': 4950, 'TREX': 2400}

# %%
dict1={"NFLX":4950,"TREX":2400,"FIZZ":1800, "XPO":1700}

# %%
dict2 = {i:j for i,j in dict1.items() if j > 2000}
print(dict2)

# %%
dict2 = {i:dict1[i] for i in dict1 if dict1[i] > 2000}
print(dict2)
# Out:
# {'NFLX': 4950, 'TREX': 2400}

# %%
s1 = {}
print(type(s1))
s2 = {1, 2}
print(type(s2))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
s1 = set("Using dict comprehension and a conditional argument create a dictionary from the current dictionary dict1")
s2 = set([chr(i) for i in range(97,123)])
print(s2 - s1)
# Out:
# {'k', 'b', 'j', 'v', 'w', 'z', 'x', 'q'}

# %%
b = f(a, copy = true)
# 새로운 메모리 공간 할당을 위한 인자 설정
