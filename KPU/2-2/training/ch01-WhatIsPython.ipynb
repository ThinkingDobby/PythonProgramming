# %% [markdown]
# # Chapter1. WhatIsPython

# %% [markdown]
# ### 주피터 기능 - 마지막 반환값 출력

# %%
a = 10

# %%
a
# Out:
# 10

# %% [markdown]
# ### 반복문

# %%
for i, j in {"a": 1, "b": 2, "c": 3}.items():
    print(i)
# Out:
# a
# b
# c

# %% [markdown]
# ### 파이썬의 동적 바인딩

# %%
def add(a, b):
    return a + b

# %%
add(3, 5)
# Out:
# 8
